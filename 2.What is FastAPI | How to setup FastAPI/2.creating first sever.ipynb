# %% [markdown]
# <a href="https://colab.research.google.com/github/pande17827/FastApi/blob/main/2.What%20is%20FastAPI%20%7C%20How%20to%20setup%20FastAPI/2.creating%20first%20sever.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install fastapi uvicorn pydantic
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 4.3 MB/s eta 0:00:00
# ...

# %%
# !pip install nest-asyncio pyngrok

# %% [markdown]
# # <b><u><i> Method1:- running the code in normal .py file

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # <b><u><i> Method2:- running the code in normal .ipynb(jupyter) file

# %%
# !ngrok config add-authtoken 2tIkqgWNUtPxz3L5w4cePDF8D0V_6wYsGqKSkNv2wHbHGFcsH
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from fastapi import FastAPI
import nest_asyncio
from pyngrok import ngrok
import uvicorn

app = FastAPI()

# first router for first endpoint
@app.get("/")
def Hello():
  return {"Message":"Hello World"}

@app.get('/about')
def about():
  return {"message":"this is the homepage of campusx"}

# Apply nest_asyncio to allow running uvicorn inside notebook
nest_asyncio.apply()

# Open an ngrok tunnel to the default uvicorn port 8000
public_url = ngrok.connect(8000)
print(f"Public URL: {public_url}")

# Run the FastAPI app
uvicorn.run(app, host="0.0.0.0", port=8000)
# Out:
# Public URL: NgrokTunnel: "https://bf47-35-237-74-151.ngrok-free.app" -> "http://localhost:8000"
# INFO:     Started server process [705]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# INFO:     115.245.240.156:0 - "GET / HTTP/1.1" 200 OK
# INFO:     115.245.240.156:0 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# INFO:     115.245.240.156:0 - "GET /docs HTTP/1.1" 200 OK
# INFO:     115.245.240.156:0 - "GET /openapi.json HTTP/1.1" 200 OK
# INFO:     115.245.240.156:0 - "GET / HTTP/1.1" 200 OK
# INFO:     115.245.240.156:0 - "GET / HTTP/1.1" 200 OK
# INFO:     115.245.240.156:0 - "GET /about HTTP/1.1" 200 OK
# INFO:     115.245.240.156:0 - "GET /about HTTP/1.1" 200 OK
# INFO:     115.245.240.156:0 - "GET /docs HTTP/1.1" 200 OK
# INFO:     115.245.240.156:0 - "GET /openapi.json HTTP/1.1" 200 OK

# %% [markdown]
# # <b><U><i> Getting docs syntex
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # <b><u><i> Executing the endpoints

# %% [markdown]
# ![image.png](data:image/png;base64,...)
