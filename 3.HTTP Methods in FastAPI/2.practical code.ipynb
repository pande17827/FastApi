# %% [markdown]
# <a href="https://colab.research.google.com/github/pande17827/FastApi/blob/main/3.HTTP%20Methods%20in%20FastAPI/2.practical%20code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # <b><u><i> we will create there five endpoints

# %% [markdown]
# ![image.png](data:image/png;base64,...)
