# %% [markdown]
# <a href="https://colab.research.google.com/github/pande17827/FastApi/blob/main/4.Path%20%26%20Query%20Params%20in%20FastAPI/2.query%20parameters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # <b><u><i>How to implement Query:-using Query module from FastApi

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
