# %% [markdown]
# <a href="https://colab.research.google.com/github/pande17827/FastApi/blob/main/6.Serving%20ML%20Models%20with%20FastAPI/1.what%20and%20how.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")

# %% [markdown]
# ![image.png](data:image/png;base64,...)
