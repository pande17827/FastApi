# %% [markdown]
# <a href="https://colab.research.google.com/github/pande17827/FastApi/blob/main/6.Serving%20ML%20Models%20with%20FastAPI/2.creating%20model%20and%20saving%20model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # <b>Data We have

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # <b>After Applying Feature Engineering

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # <b>What we want?
# <pre>Ans:- we want to predict this class</pre>
# ![image.png](data:image/png;base64,...)
